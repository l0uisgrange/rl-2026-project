# %% [markdown]
# # IQ-Learn sweep launcher (Colab)
#
# Upload the `imitation_learning/` folder to `MyDrive/imitation_learning/` and run the cells below in order. Total runtime is around 4.5 hours on CPU.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# %cd /content/drive/MyDrive/imitation_learning
# !ls

# %%
# !pip install gymnasium -q

# %% [markdown]
# Smoke test (about 25 min). Confirms both envs train before launching the full sweep.

# %%
# !python run_experiments.py

# %% [markdown]
# Full sweep (2 envs x 5 K values x 3 seeds = 30 runs). Outputs go to `logs/`.

# %%
# !python run_experiments.py --full

# %%
# !zip -r logs.zip logs/
from google.colab import files
files.download('logs.zip')
